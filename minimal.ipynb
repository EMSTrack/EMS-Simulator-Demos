# %%
from ems.run import Driver
driver = Driver('examples/minimal.yaml')
sim, data = driver.create_simulator()
# Out:
# /usr/local/lib/python3.7/site-packages/ems/run.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   kwargs.update(yaml.load(open(config_location, 'r')))

# %%
sim.run()
# Out:
# Current Time: 2019-01-31 00:15:14.100000
# Processing new case: 1
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.8878264936992, -117.22489692920144
# Duration: 0:13:08
# Distance Accuracy: None
# Busy ambulances: ['0']
# Ongoing cases: [1]
# Pending cases: []
#
# Metrics
# ...
# Current Time: 2019-01-31 00:26:29.100000
# Processing new case: 2
# Selected ambulance: 4
# Started new event: Heading to Incident
# Destination: 32.88797964026463, -117.24926280537653
# Duration: 0:19:10
# Distance Accuracy: None
# Busy ambulances: ['0', '4']
# Ongoing cases: [1, 2]
# Pending cases: []
#
# Metrics
# ...
# Current Time: 2019-01-31 00:28:22.100000
# Processing ongoing case: 1
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.8878264936992, -117.22489692920144
# Duration: 0:14:05
# Distance Difference: None
# Busy ambulances: ['0', '4']
# Ongoing cases: [1, 2]
# Pending cases: []
#
# Metrics
# ...
