# %%
from ems.run import Driver

# %% [markdown]
# ## Initialize Simulation

# %%
driver = Driver('examples/simple.yaml')
sim, data = driver.create_simulator()

# %% [markdown]
# ## Run Simulation

# %%
results = sim.run()
# Out:
# Current Time: 2019-01-31 00:06:51.100000
# Processing new case: 1
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.72233291884531, -117.04885977632645
# Duration: 0:01:24
# Distance Accuracy: -0.97%
# Busy ambulances: [2]
# Ongoing cases: [1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:06:51.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:08:15.100000
# Processing ongoing case: 1
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.72233291884531, -117.04885977632645
# Duration: 0:09:31
# Distance Difference: None
# Busy ambulances: [2]
# Ongoing cases: [1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:08:15.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:10:00.100000
# Processing new case: 2
# Selected ambulance: 1
# Started new event: Heading to Incident
# Destination: 32.80024726674799, -117.08640676842623
# Duration: 0:00:43
# Distance Accuracy: -3.02%
# Busy ambulances: [1, 2]
# Ongoing cases: [2, 1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:10:00.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:10:43.100000
# Processing ongoing case: 2
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.80024726674799, -117.08640676842623
# Duration: 0:05:24
# Distance Difference: None
# Busy ambulances: [1, 2]
# Ongoing cases: [2, 1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:10:43.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:13:28.100000
# Processing new case: 3
# Selected ambulance: 3
# Started new event: Heading to Incident
# Destination: 32.75513320332385, -117.11575928795205
# Duration: 0:01:41
# Distance Accuracy: -11.46%
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [3, 2, 1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:13:28.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:15:09.100000
# Processing ongoing case: 3
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.75513320332385, -117.11575928795205
# Duration: 0:07:47
# Distance Difference: None
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [2, 1, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:15:09.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:16:07.100000
# Processing ongoing case: 2
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:01:45
# Distance Difference: -1.79%
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [1, 2, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:16:07.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:17:46.100000
# Processing ongoing case: 1
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:00:06
# Distance Difference: -27.81%
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [1, 2, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:17:46.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:17:52.100000
# Processing ongoing case: 1
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:05:40
# Distance Difference: None
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [2, 3, 1]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:17:52.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:17:52.100000
# Processing ongoing case: 2
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:07:02
# Distance Difference: None
# Busy ambulances: [1, 2, 3]
# Ongoing cases: [3, 1, 2]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:17:52.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:19:39.100000
# Processing new case: 4
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.7978107003661, -117.02766275541329
# Duration: 0:05:18
# Distance Accuracy: -2.53%
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [3, 1, 2, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:19:39.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:22:56.100000
# Processing ongoing case: 3
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:01:15
# Distance Difference: -14.8%
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [1, 3, 2, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:22:56.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:23:32.100000
# Processing ongoing case: 1
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.7164309993765, -117.0723066414098
# Duration: 0:01:24
# Distance Difference: -5.9%
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [3, 2, 1, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:23:32.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:24:11.100000
# Processing ongoing case: 3
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:08:01
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [2, 1, 4, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:24:11.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:24:36.100000
# Processing new case: 5
# Selected ambulance: 4
# Started new event: Heading to Incident
# Destination: 32.78692178018396, -117.08363003519432
# Duration: 0:04:35
# Distance Accuracy: 0.95%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [2, 1, 4, 5, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:24:36.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:24:54.100000
# Processing ongoing case: 2
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.79374549341401, -117.07624692996806
# Duration: 0:01:52
# Distance Difference: 6.22%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [1, 4, 2, 5, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:24:54.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:24:56.100000
# Processing ongoing case: 1
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [4, 2, 5, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:24:56.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:24:57.100000
# Processing ongoing case: 4
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.7978107003661, -117.02766275541329
# Duration: 0:08:16
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [2, 5, 3, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:24:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:26:46.100000
# Processing ongoing case: 2
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 3, 4]
# Ongoing cases: [5, 3, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:26:46.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:29:11.100000
# Processing ongoing case: 5
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.78692178018396, -117.08363003519432
# Duration: 0:06:06
# Distance Difference: None
# Busy ambulances: [0, 3, 4]
# Ongoing cases: [3, 4, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:29:11.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:30:54.100000
# Processing new case: 6
# Selected ambulance: 1
# Started new event: Heading to Incident
# Destination: 32.79314377929144, -117.01909108988052
# Duration: 0:03:07
# Distance Accuracy: -5.93%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [3, 4, 6, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:30:54.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:32:12.100000
# Processing ongoing case: 3
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.782791392470024, -117.11856544521162
# Duration: 0:03:08
# Distance Difference: -3.77%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [4, 6, 5, 3]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:32:12.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:33:13.100000
# Processing ongoing case: 4
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:04:22
# Distance Difference: -0.26%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [6, 5, 3, 4]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:33:13.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:34:01.100000
# Processing ongoing case: 6
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.79314377929144, -117.01909108988052
# Duration: 0:09:34
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [5, 3, 4, 6]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:34:01.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:35:17.100000
# Processing ongoing case: 5
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:00:50
# Distance Difference: -25.47%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [3, 5, 4, 6]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:35:17.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:35:20.100000
# Processing ongoing case: 3
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 4]
# Ongoing cases: [5, 4, 6]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:35:20.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:36:07.100000
# Processing ongoing case: 5
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:09:08
# Distance Difference: None
# Busy ambulances: [0, 1, 4]
# Ongoing cases: [4, 6, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:36:07.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:36:24.100000
# Processing new case: 7
# Selected ambulance: 3
# Started new event: Heading to Incident
# Destination: 32.770133447238976, -117.14898658646472
# Duration: 0:01:52
# Distance Accuracy: -5.37%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [4, 7, 6, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:36:24.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:37:35.100000
# Processing ongoing case: 4
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:05:05
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [7, 4, 6, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:37:35.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:38:16.100000
# Processing ongoing case: 7
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.770133447238976, -117.14898658646472
# Duration: 0:05:49
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [4, 6, 7, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:38:16.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:42:31.100000
# Processing new case: 8
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.799348007734885, -117.03615981814372
# Duration: 0:06:07
# Distance Accuracy: 0.5%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [4, 6, 7, 5, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:42:31.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:42:40.100000
# Processing ongoing case: 4
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.737651457045004, -117.0884107741496
# Duration: 0:02:47
# Distance Difference: 1.9%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [6, 7, 5, 4, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:42:40.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:43:35.100000
# Processing ongoing case: 6
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:04:37
# Distance Difference: -3.07%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [7, 5, 4, 6, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:43:35.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:44:05.100000
# Processing ongoing case: 7
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:02:37
# Distance Difference: -2.2%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [5, 4, 7, 6, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:44:05.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:45:15.100000
# Processing ongoing case: 5
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.762912192231056, -117.15633260051138
# Duration: 0:03:31
# Distance Difference: 1.27%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [4, 7, 6, 8, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:45:15.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:45:27.100000
# Processing ongoing case: 4
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [7, 6, 8, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:45:27.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:46:09.100000
# Processing new case: 9
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.728660457122146, -117.12566985935068
# Duration: 0:02:14
# Distance Accuracy: -0.33%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [7, 6, 9, 8, 5]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:46:09.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:46:42.100000
# Processing ongoing case: 7
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:07:21
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [6, 9, 8, 5, 7]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:46:42.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:48:12.100000
# Processing ongoing case: 6
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:06:02
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [9, 8, 5, 7, 6]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:48:12.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:48:23.100000
# Processing ongoing case: 9
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.728660457122146, -117.12566985935068
# Duration: 0:07:51
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [8, 5, 7, 6, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:48:23.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:48:38.100000
# Processing ongoing case: 8
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.799348007734885, -117.03615981814372
# Duration: 0:05:06
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [5, 8, 7, 6, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:48:38.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:48:46.100000
# Processing ongoing case: 5
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [8, 7, 6, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:48:46.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:52:11.100000
# Processing new case: 10
# Selected ambulance: 4
# Started new event: Heading to Incident
# Destination: 32.815197808762136, -117.08142374501284
# Duration: 0:05:35
# Distance Accuracy: -1.17%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [8, 7, 6, 9, 10]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:52:11.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:53:44.100000
# Processing ongoing case: 8
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:04:06
# Distance Difference: 3.79%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [7, 6, 9, 10, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:53:44.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:54:03.100000
# Processing ongoing case: 7
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.782791392470024, -117.11856544521162
# Duration: 0:03:08
# Distance Difference: -3.77%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [6, 9, 7, 10, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:54:03.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:54:14.100000
# Processing ongoing case: 6
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.79374549341401, -117.07624692996806
# Duration: 0:01:52
# Distance Difference: 6.22%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [6, 9, 7, 10, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:54:14.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:55:15.100000
# New case arrived but no available ambulance; Case pending
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [6, 9, 7, 10, 8]
# Pending cases: [11]
#
# Metrics
# timestamp: 2019-01-31 00:55:15.100000
# total_delay: 0:00:00
# count_pending: 1
# ================================================================================
# Current Time: 2019-01-31 00:56:06.100000
# Processing ongoing case: 6
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [9, 7, 10, 8]
# Pending cases: [11]
#
# Metrics
# timestamp: 2019-01-31 00:56:06.100000
# total_delay: 0:00:51
# count_pending: 1
# ================================================================================
# Current Time: 2019-01-31 00:56:06.100000
# Processing pending case: 11
# Selected ambulance: 1
# Started new event: Heading to Incident
# Destination: 32.787755358934696, -117.08430596105678
# Duration: 0:00:29
# Distance Accuracy: -22.51%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [9, 11, 7, 10, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:56:06.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:56:14.100000
# Processing ongoing case: 9
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:00:47
# Distance Difference: 53.8%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [11, 9, 7, 10, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:56:14.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:56:35.100000
# Processing ongoing case: 11
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.787755358934696, -117.08430596105678
# Duration: 0:09:43
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [9, 7, 10, 8, 11]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:56:35.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:57:01.100000
# Processing ongoing case: 9
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:09:57
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [7, 10, 8, 11, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:57:01.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:57:11.100000
# Processing ongoing case: 7
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 2, 4]
# Ongoing cases: [10, 8, 11, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:57:11.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:57:46.100000
# Processing ongoing case: 10
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.815197808762136, -117.08142374501284
# Duration: 0:09:02
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 4]
# Ongoing cases: [8, 11, 10, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:57:46.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 00:57:50.100000
# Processing ongoing case: 8
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:05:46
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 4]
# Ongoing cases: [8, 11, 10, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 00:57:50.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:01:45.100000
# Processing new case: 12
# Selected ambulance: 3
# Started new event: Heading to Incident
# Destination: 32.7942513463706, -117.048683162059
# Duration: 0:04:09
# Distance Accuracy: 0.23%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [8, 12, 11, 10, 9]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:01:45.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:03:36.100000
# Processing ongoing case: 8
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.7164309993765, -117.0723066414098
# Duration: 0:04:16
# Distance Difference: -3.32%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [12, 11, 10, 9, 8]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:03:36.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:05:54.100000
# Processing ongoing case: 12
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.7942513463706, -117.048683162059
# Duration: 0:09:03
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [11, 10, 9, 8, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:05:54.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:06:18.100000
# Processing ongoing case: 11
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:00:50
# Distance Difference: -26.0%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [10, 9, 11, 8, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:06:18.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:06:48.100000
# Processing ongoing case: 10
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:02:40
# Distance Difference: -6.2%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [9, 11, 8, 10, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:06:48.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:06:58.100000
# Processing ongoing case: 9
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.737651457045004, -117.0884107741496
# Duration: 0:02:20
# Distance Difference: 4.36%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [11, 8, 9, 10, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:06:58.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:07:08.100000
# Processing ongoing case: 11
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:06:40
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [8, 9, 10, 11, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:07:08.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:07:52.100000
# Processing ongoing case: 8
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [9, 10, 11, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:07:52.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:07:53.100000
# Processing new case: 13
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.778273419824394, -117.12733380080307
# Duration: 0:05:19
# Distance Accuracy: -0.09%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [9, 10, 13, 11, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:07:53.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:09:18.100000
# Processing ongoing case: 9
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [10, 13, 11, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:09:18.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:09:28.100000
# Processing ongoing case: 10
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:07:50
# Distance Difference: None
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [13, 11, 12, 10]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:09:28.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:13:12.100000
# Processing ongoing case: 13
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.778273419824394, -117.12733380080307
# Duration: 0:06:54
# Distance Difference: None
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [11, 12, 10, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:13:12.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:13:48.100000
# Processing ongoing case: 11
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.79374549341401, -117.07624692996806
# Duration: 0:01:52
# Distance Difference: 6.22%
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [12, 11, 10, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:13:48.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:14:47.100000
# Processing new case: 14
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.72159726932925, -117.05391494110464
# Duration: 0:02:17
# Distance Accuracy: 0.26%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [12, 11, 14, 10, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:14:47.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:14:57.100000
# Processing ongoing case: 12
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:03:18
# Distance Difference: 4.53%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [11, 14, 10, 12, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:14:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:15:40.100000
# Processing ongoing case: 11
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [14, 10, 12, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:15:40.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:17:04.100000
# Processing ongoing case: 14
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.72159726932925, -117.05391494110464
# Duration: 0:07:04
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [10, 12, 13, 14]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:17:04.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:17:18.100000
# Processing ongoing case: 10
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.762912192231056, -117.15633260051138
# Duration: 0:03:31
# Distance Difference: 1.27%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [12, 13, 10, 14]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:17:18.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:18:15.100000
# Processing ongoing case: 12
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:06:22
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [13, 10, 14, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:18:15.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:20:06.100000
# Processing ongoing case: 13
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:01:55
# Distance Difference: 15.28%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [10, 13, 14, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:20:06.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:20:24.100000
# Processing new case: 15
# Selected ambulance: 1
# Started new event: Heading to Incident
# Destination: 32.780331931937816, -117.14470238444694
# Duration: 0:03:59
# Distance Accuracy: -2.45%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [10, 13, 14, 15, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:20:24.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:20:49.100000
# Processing ongoing case: 10
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [13, 14, 15, 12]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:20:49.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:22:01.100000
# Processing ongoing case: 13
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:07:00
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [14, 15, 12, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:22:01.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:24:08.100000
# Processing ongoing case: 14
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:00:30
# Distance Difference: 30.5%
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [15, 12, 14, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:24:08.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:24:23.100000
# Processing ongoing case: 15
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.780331931937816, -117.14470238444694
# Duration: 0:06:57
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [12, 14, 13, 15]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:24:23.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:24:37.100000
# Processing ongoing case: 12
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.782791392470024, -117.11856544521162
# Duration: 0:01:27
# Distance Difference: 17.64%
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [14, 12, 13, 15]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:24:37.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:24:38.100000
# Processing ongoing case: 14
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:07:23
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [12, 13, 15, 14]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:24:38.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:25:11.100000
# Processing new case: 16
# Selected ambulance: 4
# Started new event: Heading to Incident
# Destination: 32.77797992328048, -117.01904246781857
# Duration: 0:08:02
# Distance Accuracy: -0.22%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [12, 13, 15, 14, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:25:11.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:26:04.100000
# Processing ongoing case: 12
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 2, 4]
# Ongoing cases: [13, 15, 14, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:26:04.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:29:01.100000
# Processing ongoing case: 13
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.7164309993765, -117.0723066414098
# Duration: 0:04:16
# Distance Difference: -3.32%
# Busy ambulances: [0, 1, 2, 4]
# Ongoing cases: [15, 14, 16, 13]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:29:01.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:30:08.100000
# Processing new case: 17
# Selected ambulance: 3
# Started new event: Heading to Incident
# Destination: 32.806412744193146, -117.03404958456623
# Duration: 0:05:15
# Distance Accuracy: 1.44%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [15, 14, 16, 13, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:30:08.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:31:20.100000
# Processing ongoing case: 15
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:02:37
# Distance Difference: -2.73%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [14, 16, 13, 15, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:31:20.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:32:01.100000
# Processing ongoing case: 14
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.737651457045004, -117.0884107741496
# Duration: 0:02:33
# Distance Difference: 2.24%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [16, 13, 15, 14, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:32:01.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:33:13.100000
# Processing ongoing case: 16
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.77797992328048, -117.01904246781857
# Duration: 0:05:11
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [13, 15, 14, 17, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:33:13.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:33:17.100000
# Processing ongoing case: 13
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [15, 14, 17, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:33:17.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:33:57.100000
# Processing ongoing case: 15
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:06:24
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [14, 17, 16, 15]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:33:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:34:34.100000
# Processing ongoing case: 14
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [1, 3, 4]
# Ongoing cases: [17, 16, 15]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:34:34.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:35:23.100000
# Processing ongoing case: 17
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.806412744193146, -117.03404958456623
# Duration: 0:06:02
# Distance Difference: None
# Busy ambulances: [1, 3, 4]
# Ongoing cases: [16, 15, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:35:23.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:36:13.100000
# Processing new case: 18
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.74991292595493, -117.12736586811432
# Duration: 0:02:16
# Distance Accuracy: -6.07%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [16, 18, 15, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:36:13.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:38:24.100000
# Processing ongoing case: 16
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:04:14
# Distance Difference: 4.45%
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [18, 15, 17, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:38:24.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:38:29.100000
# Processing ongoing case: 18
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.74991292595493, -117.12736586811432
# Duration: 0:06:49
# Distance Difference: None
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [15, 17, 16, 18]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:38:29.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:39:14.100000
# Processing new case: 19
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.80649627972804, -117.16051212154386
# Duration: 0:08:07
# Distance Accuracy: 0.77%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [15, 17, 16, 18, 19]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:39:14.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:40:21.100000
# Processing ongoing case: 15
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.79374549341401, -117.07624692996806
# Duration: 0:01:52
# Distance Difference: 6.22%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [17, 15, 16, 18, 19]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:40:21.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:41:25.100000
# Processing ongoing case: 17
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:04:30
# Distance Difference: 5.19%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [15, 16, 18, 17, 19]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:41:25.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:42:13.100000
# Processing ongoing case: 15
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [16, 18, 17, 19]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:42:13.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:42:38.100000
# Processing ongoing case: 16
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.724462, -117.048276
# Duration: 0:09:26
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [18, 17, 19, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:42:38.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:45:18.100000
# Processing ongoing case: 18
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:00:45
# Distance Difference: -20.19%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [17, 18, 19, 16]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:45:18.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:45:55.100000
# Processing ongoing case: 17
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:07:38
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [18, 19, 16, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:45:55.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-01-31 01:45:56.100000
# Processing new case: 20
# Selected ambulance: 1
# Started new event: Heading to Incident
# Destination: 32.712456573832505, -117.08008708014285
# Duration: 0:05:39
# Distance Accuracy: 1.04%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [18, 19, 20, 16, 17]
# Pending cases: []
#
# Metrics
# timestamp: 2019-01-31 01:45:56.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# ...
# count_pending: 2
# ================================================================================
# Current Time: 2019-02-01 17:35:42.100000
# Processing ongoing case: 492
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 2, 3]
# Ongoing cases: [496, 493, 495, 494]
# Pending cases: [497, 498]
#
# Metrics
# timestamp: 2019-02-01 17:35:42.100000
# total_delay: 0:09:49
# count_pending: 2
# ================================================================================
# Current Time: 2019-02-01 17:35:42.100000
# Processing pending case: 497
# Selected ambulance: 4
# Started new event: Heading to Incident
# Destination: 32.76748567861607, -117.16073127280701
# Duration: 0:00:25
# Distance Accuracy: 2.95%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [496, 497, 493, 495, 494]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:35:42.100000
# total_delay: 0:01:50
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:35:49.100000
# Processing ongoing case: 496
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:06:09
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [497, 493, 495, 494, 496]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:35:49.100000
# total_delay: 0:01:57
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:36:07.100000
# Processing ongoing case: 497
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.76748567861607, -117.16073127280701
# Duration: 0:08:50
# Distance Difference: None
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [493, 495, 494, 496, 497]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:36:07.100000
# total_delay: 0:02:15
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:36:24.100000
# Processing ongoing case: 493
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.7164309993765, -117.0723066414098
# Duration: 0:04:16
# Distance Difference: -3.32%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [495, 494, 493, 496, 497]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:36:24.100000
# total_delay: 0:02:32
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:38:16.100000
# Processing ongoing case: 495
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.737651457045004, -117.0884107741496
# Duration: 0:02:47
# Distance Difference: 1.9%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [494, 493, 495, 496, 497]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:38:16.100000
# total_delay: 0:04:24
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:38:59.100000
# Processing ongoing case: 494
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.782791392470024, -117.11856544521162
# Duration: 0:05:45
# Distance Difference: 0.41%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [493, 495, 496, 494, 497]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:38:59.100000
# total_delay: 0:05:07
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:40:40.100000
# Processing ongoing case: 493
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 1, 3, 4]
# Ongoing cases: [495, 496, 494, 497]
# Pending cases: [498]
#
# Metrics
# timestamp: 2019-02-01 17:40:40.100000
# total_delay: 0:06:48
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:40:40.100000
# Processing pending case: 498
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.713099499486525, -117.12769292301596
# Duration: 0:03:17
# Distance Accuracy: 1.64%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [495, 496, 498, 494, 497]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:40:40.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:40:42.100000
# New case arrived but no available ambulance; Case pending
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [495, 496, 498, 494, 497]
# Pending cases: [499]
#
# Metrics
# timestamp: 2019-02-01 17:40:42.100000
# total_delay: 0:00:00
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:41:03.100000
# Processing ongoing case: 495
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [1, 2, 3, 4]
# Ongoing cases: [496, 498, 494, 497]
# Pending cases: [499]
#
# Metrics
# timestamp: 2019-02-01 17:41:03.100000
# total_delay: 0:00:21
# count_pending: 1
# ================================================================================
# Current Time: 2019-02-01 17:41:03.100000
# Processing pending case: 499
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.81859187423045, -117.02442144607555
# Duration: 0:06:49
# Distance Accuracy: 1.76%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [496, 498, 494, 497, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:41:03.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:41:58.100000
# Processing ongoing case: 496
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.79374549341401, -117.07624692996806
# Duration: 0:01:52
# Distance Difference: 6.22%
# Busy ambulances: [0, 1, 2, 3, 4]
# Ongoing cases: [496, 498, 494, 497, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:41:58.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:43:50.100000
# Processing ongoing case: 496
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [498, 494, 497, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:43:50.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:43:57.100000
# Processing ongoing case: 498
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.713099499486525, -117.12769292301596
# Duration: 0:07:23
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [494, 497, 499, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:43:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:44:44.100000
# Processing ongoing case: 494
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 4]
# Ongoing cases: [497, 499, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:44:44.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:44:57.100000
# Processing ongoing case: 497
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:03:00
# Distance Difference: 2.95%
# Busy ambulances: [0, 2, 4]
# Ongoing cases: [499, 497, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:44:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:46:55.100000
# Processing new case: 500
# Selected ambulance: 3
# Started new event: Heading to Incident
# Destination: 32.793954571627125, -117.14307636574327
# Duration: 0:01:28
# Distance Accuracy: -9.37%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [499, 497, 500, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:46:55.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:47:52.100000
# Processing ongoing case: 499
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.81859187423045, -117.02442144607555
# Duration: 0:05:46
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [497, 500, 498, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:47:52.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:47:57.100000
# Processing ongoing case: 497
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:09:16
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [500, 498, 499, 497]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:47:57.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:48:23.100000
# Processing ongoing case: 500
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.793954571627125, -117.14307636574327
# Duration: 0:09:08
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [498, 499, 497, 500]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:48:23.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:51:20.100000
# Processing ongoing case: 498
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:01:47
# Distance Difference: 13.76%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [498, 499, 497, 500]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:51:20.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:53:07.100000
# Processing ongoing case: 498
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.736006, -117.127023
# Duration: 0:05:21
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [499, 497, 500, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:53:07.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:53:38.100000
# Processing ongoing case: 499
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:05:09
# Distance Difference: -0.76%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [497, 500, 498, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:53:38.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:57:13.100000
# Processing ongoing case: 497
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.762912192231056, -117.15633260051138
# Duration: 0:02:11
# Distance Difference: -12.95%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [500, 498, 499, 497]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:57:13.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:57:31.100000
# Processing ongoing case: 500
# Finished event: Attending to Incident
# Started new event: Heading to Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:02:53
# Distance Difference: 1.26%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [498, 499, 497, 500]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:57:31.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:58:28.100000
# Processing ongoing case: 498
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.7164309993765, -117.0723066414098
# Duration: 0:03:39
# Distance Difference: 5.82%
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [499, 497, 500, 498]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:58:28.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:58:47.100000
# Processing ongoing case: 499
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:08:36
# Distance Difference: None
# Busy ambulances: [0, 2, 3, 4]
# Ongoing cases: [497, 500, 498, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:58:47.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 17:59:24.100000
# Processing ongoing case: 497
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 2, 3]
# Ongoing cases: [500, 498, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 17:59:24.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:00:24.100000
# Processing ongoing case: 500
# Finished event: Heading to Hospital
# Started new event: Dropping off Patient at Hospital
# Destination: 32.776485, -117.09868
# Duration: 0:05:55
# Distance Difference: None
# Busy ambulances: [0, 2, 3]
# Ongoing cases: [498, 500, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:00:24.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:02:07.100000
# Processing ongoing case: 498
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0, 3]
# Ongoing cases: [500, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:02:07.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:06:19.100000
# Processing ongoing case: 500
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.782791392470024, -117.11856544521162
# Duration: 0:01:27
# Distance Difference: 17.64%
# Busy ambulances: [0, 3]
# Ongoing cases: [499, 500]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:06:19.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:07:23.100000
# Processing ongoing case: 499
# Finished event: Dropping off Patient at Hospital
# Started new event: Returning to Base
# Destination: 32.737651457045004, -117.0884107741496
# Duration: 0:02:47
# Distance Difference: 1.9%
# Busy ambulances: [0, 3]
# Ongoing cases: [500, 499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:07:23.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:07:46.100000
# Processing ongoing case: 500
# Finished event: Returning to Base
# Case finished
# Busy ambulances: [0]
# Ongoing cases: [499]
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:07:46.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================
# Current Time: 2019-02-01 18:10:10.100000
# Processing ongoing case: 499
# Finished event: Returning to Base
# Case finished
# Busy ambulances: []
# Ongoing cases: []
# Pending cases: []
#
# Metrics
# timestamp: 2019-02-01 18:10:10.100000
# total_delay: 0:00:00
# count_pending: 0
# ================================================================================

# %% [markdown]
# ## Graph Some Results

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

records = results.case_records

# %%
print("Number of Cases: {}".format(len(records)))
# Out:
# Number of Cases: 500

# %%
selected_ambulances = [record.ambulance.id for record in records]
groupings = defaultdict(lambda: 0)
for identifier in selected_ambulances:
    groupings[identifier] += 1

fig, ax = plt.subplots(figsize=(10, 4))
plt.bar(groupings.keys(), groupings.values(), color="seagreen")
plt.xlabel('Ambulance Identifier')
plt.ylabel('Frequency of Selection')
plt.title('Ambulance Selection Frequency')
plt.show()

# %%
from datetime import timedelta

# First 50 cases
case_dates = [record.case.date_recorded for record in records[:50]]

fig, ax = plt.subplots(figsize=(16,2))
ax.scatter(case_dates, [1]*len(case_dates),marker='o', s=50)
fig.autofmt_xdate()

ax.yaxis.set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

ax.get_yaxis().set_ticklabels([])
plt.xlim(case_dates[0] - timedelta(minutes=20), case_dates[-1] + timedelta(minutes=20))
plt.title('Emergency Call Distribution for First 50 Cases')
plt.show()

# %%
case_locations = [record.case.incident_location for record in records]
latitudes = [l.latitude for l in case_locations]
longitudes = [l.longitude for l in case_locations]

fig, ax = plt.subplots(figsize=(8, 8))
ax.ticklabel_format(useOffset=False)
plt.scatter(latitudes, longitudes, color="teal")
plt.title("Case Locations")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid()
plt.show()

# %% [markdown]
# ## Graph Metrics

# %%
metrics = sim.get_metrics()

# %%
timestamps = [m['timestamp'] for m in metrics]
delays = [m['total_delay'].total_seconds() for m in metrics]
pendings = [m['count_pending'] for m in metrics]

# Filter for smoother results
timestamps = timestamps[::14]
delays = delays[::14]
pendings = pendings[::14]

# %%
plt.figure(figsize=(15, 7))
plt.plot(timestamps, delays, color="indianred")
plt.title('Total Simulated Case Delay')
plt.xlabel('Time')
plt.ylabel("Number of Seconds of Delay")
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(timestamps, pendings, color="darkviolet")
plt.title('Total Number of Pending Cases')
plt.xlabel('Time')
plt.ylabel("Number of Pending Cases")
plt.show()
